# %%
# fix relative imports
import os
cwd = os.path.normpath(os.getcwd())
cwd = cwd.split(os.sep)
find = cwd.index("fidelity-phase-tran")
newdir = f"{os.sep}".join(cwd[:find+1])
os.chdir(newdir)
# %load_ext autoreload
# %autoreload 2

import numpy as np
import uuid
import time
import pickle
import gzip
from functools import partial

from tqdm.notebook import tqdm
from tenpy.tools import hdf5_io
import h5py

import matplotlib.pyplot as plt

from qphaset.annni import model_annni_qs_mps
from qphaset.models import drmg_gstate_qs_mps

# %% [markdown]
# ## Template notebook for running the DMRG for the ANNNI model with `qs-mps`

# %%
def guess_state(L):
    """
    guess_state

    This function gives you a product state tensor of all up spins
    for a chain of length L
    
    """
    up = np.array([[[1],[0]]])
    init_tensor = [up for _ in range(L)]
    return init_tensor

def run_model(params, model_factory, gstate_solver):
    t_tot = []
    g_states = []
    for (x,y) in tqdm(params):
        print(f"x: {x}, y:{y}")
        model = model_factory(x, y)
        try:
            print("try with guess state...")
            if y == params[0,-1]:
                init_tensor = guess_state(model.L)
                model.sites = init_tensor.copy()
                model.enlarge_chi()
            else:
                model.sites = init_tensor.copy()
            timer = time.monotonic()
            gstate = gstate_solver(model=model)
            timer = time.monotonic() - timer
        except:
            print("try with random state...")
            model._random_state(seed=3, type_shape="rectangular")
            model.canonical_form()
            timer = time.monotonic()
            gstate = gstate_solver(model=model)
            timer = time.monotonic() - timer
        t_tot.append(timer)
        g_states.append(model.sites.copy())
        init_tensor = model.sites.copy()
    statistics = dict(times=t_tot)
    return g_states, statistics

# %%
# *** Data sampling (Hamitonian parameters grid) ***

n = 10  # Sampling grid size

# params = np.linspace(0.01, 1.5, n), np.linspace(0.01, 1.5, n)
params = np.linspace(0.1, 1.5, n), np.linspace(1.5, 0.1, n) # upside-down
# params = np.linspace(0.01, 1., n), np.linspace(1., 0.01, n)   # Good one
# params = np.linspace(0.5, 1.5, n), np.linspace(1., 0.2, n)      # Floating phase detail
# params = np.linspace(0.5, 1.5, n), np.linspace(0.8, 0.01, n)      # Floating phase detail (lowered)
# params = np.linspace(0.01, 1., n), np.linspace(0.8, 0.01, n)      # Floating phase detail (lowered) + multi-critical point
# params = np.linspace(0.6, 1.5, n), np.linspace(0.1, 1.5, n)      # Floating phase detail ++

params = map(lambda m: m.flatten(), np.meshgrid(*params, indexing='xy'))
params = tuple(params)
params = np.stack(params).T

# %%
# *** Config ***

l = 20  # Number of spins

model_name = 'ANNNI'
model_factory = partial(model_annni_qs_mps, c1=-1, chi=64)
dmrg_params = {
    #'mixer': True,
    #'max_E_err': 1.e-16,
    #'chi_list': {0: 25, 10: 50, 20: 100},
    'type_shape': "rectangular",
    'trunc_params': {
       'trunc_tol': False,
       'trunc_chi': True
    #   'svd_min': 1.e-16
    },
    'd': 2,
    'max_hours': 16 / 3600
    #'combine': True
}

# %%
# *** Solver ***

gstates, stats = run_model(params,
                        model_factory=partial(model_factory, l=l),
                        gstate_solver=partial(drmg_gstate_qs_mps, dmrg_params=dmrg_params))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# x: 0.1, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.475811051001074
# ##############################
# x: 0.25555555555555554, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.1475980169998365
# ##############################
# x: 0.4111111111111111, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.0386669950003125
# ##############################
# x: 0.5666666666666667, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.4543046220005635
# ##############################
# x: 0.7222222222222222, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.4001565590006066
# ##############################
# x: 0.8777777777777778, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.2957820459996583
# ##############################
# x: 1.0333333333333334, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.47167890899982
# ##############################
# x: 1.188888888888889, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.6432724989990675
# ##############################
# x: 1.3444444444444446, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.9128720100015926
# ##############################
# x: 1.5, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.354072162001103
# ##############################
# x: 0.1, y:1.3444444444444446
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.8270895709993056
# ##############################
# x: 0.25555555555555554, y:1.3444444444444446
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.4908721540014085
# ##############################
# x: 0.4111111111111111, y:1.3444444444444446
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.456884238001294
# ##############################
# x: 0.5666666666666667, y:1.3444444444444446
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.477146741000979
# ##############################
# x: 0.7222222222222222, y:1.3444444444444446
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.785622407000119
# ##############################
# x: 0.8777777777777778, y:1.3444444444444446
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.9539008579995425
# ##############################
# x: 1.0333333333333334, y:1.3444444444444446
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.057101487000182
# ##############################
# x: 1.188888888888889, y:1.3444444444444446
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.343967529999645
# ##############################
# x: 1.3444444444444446, y:1.3444444444444446
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.572325187999013
# ##############################
# x: 1.5, y:1.3444444444444446
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.365439051000067
# ##############################
# x: 0.1, y:1.1888888888888889
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.8312966249995952
# ##############################
# x: 0.25555555555555554, y:1.1888888888888889
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.8550501279987657
# ##############################
# x: 0.4111111111111111, y:1.1888888888888889
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.415797530000418
# ##############################
# x: 0.5666666666666667, y:1.1888888888888889
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.622837957998854
# ##############################
# x: 0.7222222222222222, y:1.1888888888888889
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.92470629500167
# ##############################
# x: 0.8777777777777778, y:1.1888888888888889
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.167003246000604
# ##############################
# x: 1.0333333333333334, y:1.1888888888888889
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.75578864399904
# ##############################
# x: 1.188888888888889, y:1.1888888888888889
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.660465696999381
# ##############################
# x: 1.3444444444444446, y:1.1888888888888889
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.626543874999697
# ##############################
# x: 1.5, y:1.1888888888888889
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.816529128000184
# ##############################
# x: 0.1, y:1.0333333333333332
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.384830458999204
# ##############################
# x: 0.25555555555555554, y:1.0333333333333332
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.978793856000266
# ##############################
# x: 0.4111111111111111, y:1.0333333333333332
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.220211265999751
# ##############################
# x: 0.5666666666666667, y:1.0333333333333332
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.305175086999952
# ##############################
# x: 0.7222222222222222, y:1.0333333333333332
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.1965915669989045
# ##############################
# x: 0.8777777777777778, y:1.0333333333333332
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.534875045999797
# ##############################
# x: 1.0333333333333334, y:1.0333333333333332
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.851484687000266
# ##############################
# x: 1.188888888888889, y:1.0333333333333332
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.39886155000022
# ##############################
# x: 1.3444444444444446, y:1.0333333333333332
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.437867372000255
# ##############################
# x: 1.5, y:1.0333333333333332
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.24678377499913
# ##############################
# x: 0.1, y:0.8777777777777778
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.08678928000154
# ##############################
# x: 0.25555555555555554, y:0.8777777777777778
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.9785180510007194
# ##############################
# x: 0.4111111111111111, y:0.8777777777777778
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.7707801230008045
# ##############################
# x: 0.5666666666666667, y:0.8777777777777778
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.923597818999042
# ##############################
# x: 0.7222222222222222, y:0.8777777777777778
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.232381873000122
# ##############################
# x: 0.8777777777777778, y:0.8777777777777778
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.34541852700022
# ##############################
# x: 1.0333333333333334, y:0.8777777777777778
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.559217510999588
# ##############################
# x: 1.188888888888889, y:0.8777777777777778
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 5.006025243999829
# ##############################
# x: 1.3444444444444446, y:0.8777777777777778
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.6310209130006115
# ##############################
# x: 1.5, y:0.8777777777777778
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.085729906999404
# ##############################
# x: 0.1, y:0.7222222222222222
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.6504509130008955
# ##############################
# x: 0.25555555555555554, y:0.7222222222222222
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.807219229000111
# ##############################
# x: 0.4111111111111111, y:0.7222222222222222
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.822724711000774
# ##############################
# x: 0.5666666666666667, y:0.7222222222222222
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.370933805001187
# ##############################
# x: 0.7222222222222222, y:0.7222222222222222
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 5.290188758999648
# ##############################
# x: 0.8777777777777778, y:0.7222222222222222
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 5.63637209099943
# ##############################
# x: 1.0333333333333334, y:0.7222222222222222
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 5.569695190999482
# ##############################
# x: 1.188888888888889, y:0.7222222222222222
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.327784876999431
# ##############################
# x: 1.3444444444444446, y:0.7222222222222222
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.7498824009999225
# ##############################
# x: 1.5, y:0.7222222222222222
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.568174275000274
# ##############################
# x: 0.1, y:0.5666666666666667
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.4618176220010355
# ##############################
# x: 0.25555555555555554, y:0.5666666666666667
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 6.570056212000054
# ##############################
# x: 0.4111111111111111, y:0.5666666666666667
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 5.272100987000158
# ##############################
# x: 0.5666666666666667, y:0.5666666666666667
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 5.190767918998972
# ##############################
# x: 0.7222222222222222, y:0.5666666666666667
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 5.604356775000269
# ##############################
# x: 0.8777777777777778, y:0.5666666666666667
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 5.8201019409989385
# ##############################
# x: 1.0333333333333334, y:0.5666666666666667
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.826806391998616
# ##############################
# x: 1.188888888888889, y:0.5666666666666667
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.680447945000196
# ##############################
# x: 1.3444444444444446, y:0.5666666666666667
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.7296857860001182
# ##############################
# x: 1.5, y:0.5666666666666667
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.3801386730010563
# ##############################
# x: 0.1, y:0.411111111111111
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.107903737000015
# ##############################
# x: 0.25555555555555554, y:0.411111111111111
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 5.361462120999931
# ##############################
# x: 0.4111111111111111, y:0.411111111111111
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 6.560759452999264
# ##############################
# x: 0.5666666666666667, y:0.411111111111111
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 6.456796258000395
# ##############################
# x: 0.7222222222222222, y:0.411111111111111
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 7.0945649499990395
# ##############################
# x: 0.8777777777777778, y:0.411111111111111
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 5.984171943000547
# ##############################
# x: 1.0333333333333334, y:0.411111111111111
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.08903553699929
# ##############################
# x: 1.188888888888889, y:0.411111111111111
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.773041202000968
# ##############################
# x: 1.3444444444444446, y:0.411111111111111
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.165988810998897
# ##############################
# x: 1.5, y:0.411111111111111
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 2.9382025039994915
# ##############################
# x: 0.1, y:0.25555555555555554
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.026484392999919
# ##############################
# x: 0.25555555555555554, y:0.25555555555555554
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.433215963999828
# ##############################
# x: 0.4111111111111111, y:0.25555555555555554
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 11.38243546800004
# ##############################
# x: 0.5666666666666667, y:0.25555555555555554
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 7.987142545000097
# ##############################
# x: 0.7222222222222222, y:0.25555555555555554
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 7.841429399000845
# ##############################
# x: 0.8777777777777778, y:0.25555555555555554
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.535800658999506
# ##############################
# x: 1.0333333333333334, y:0.25555555555555554
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.5269755980007176
# ##############################
# x: 1.188888888888889, y:0.25555555555555554
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.027518879998752
# ##############################
# x: 1.3444444444444446, y:0.25555555555555554
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 2.7636662010008877
# ##############################
# x: 1.5, y:0.25555555555555554
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 2.710596691000319
# ##############################
# x: 0.1, y:0.1
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 4.789390845999151
# ##############################
# x: 0.25555555555555554, y:0.1
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.9208383090008283
# ##############################
# x: 0.4111111111111111, y:0.1
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 7.707245878998947
# ##############################
# x: 0.5666666666666667, y:0.1
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 14.660284413001136
# ##############################
# x: 0.7222222222222222, y:0.1
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 6.076484438000989
# ##############################
# x: 0.8777777777777778, y:0.1
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.745800139000494
# ##############################
# x: 1.0333333333333334, y:0.1
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.3452349320014036
# ##############################
# x: 1.188888888888889, y:0.1
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.2716602199998306
# ##############################
# x: 1.3444444444444446, y:0.1
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 3.3153541009996843
# ##############################
# x: 1.5, y:0.1
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-10 after:
# 1 sweeps at site 2
# total iterations 39
# total time: 2.986414090000835
# ##############################

# %%
# *** Execution time per pixel ***

plt.matshow(np.array(stats['times']).reshape((n, n)), cmap='hot', origin='lower')
plt.colorbar()

# %% [markdown]
# ## Save `pickle`

# %%
# *** Data export ***

filename = f'results/data/{model_name}-{str(uuid.uuid4())}.pkl' 
data = dict(params=params, dmrg_params=dmrg_params,
            l=l, n=n, model_name=model_name,
            gstates=gstates, stats=stats)
with gzip.open(filename, 'wb') as f:
    pickle.dump(data, f)

# %% [markdown]
# ## Save `hdf5`

# %%
data = dict(params=params, dmrg_params=dmrg_params,
            l=l, n=n, model_name=model_name,
            gstates=gstates, stats=stats)

# %%
# Looking at the extent of the parameters explored (all just double checking all is okay!)
params_extent = np.concatenate([np.min(params, axis=0), np.max(params, axis=0)])
params_extent = tuple(params_extent[[0, 2, 1, 3]])
print(params_extent)
print(np.shape(params))
# Out:
# (0.1, 1.5, 0.1, 1.5)
# (100, 2)

# %%
# Taking the tensors
tensor_list =  data["gstates"]

# Convert the list to a 64x64 nested list
matrix_64x64 = [tensor_list[i*64:(i+1)*64] for i in range(64)]
# Flip the nested list vertically
flipped_matrix = matrix_64x64[::-1]
# Flatten the nested list back into a single list
corrected_list = [item for sublist in flipped_matrix for item in sublist]

# %%
# Creating data dictionary to be saved 
data_h5 = {#"gstates": gstates,  # list of MPS - tensors 
        "gstates": corrected_list, # Flipped list
        "params_extent": params_extent, # (2, N) evenly spaced - in future 
        "n": data["n"],
        "l": data["l"], # Number of qubits (L)
        "dmrg_params": data["dmrg_params"], # DMRG params used in calculation - converting? hashtable 
        "info": {"model_type":"ANNNI",}, # Additional info 
        "times": np.array(data["stats"]["times"]), # Times for DMRG } # params swept 
}

# %%
# Saving your file, make sure to change the name to the name you want to store your file in! 
filename_to_save = f"results/data/{model_name}-{str(uuid.uuid4())}.h5"
with h5py.File(filename_to_save, 'w') as f:
    hdf5_io.save_to_hdf5(f, data_h5)
