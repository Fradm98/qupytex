# %%
# fix relative imports
import os
cwd = os.path.normpath(os.getcwd())
cwd = cwd.split(os.sep)
find = cwd.index("fidelity-phase-tran")
newdir = f"{os.sep}".join(cwd[:find+1])
os.chdir(newdir)
# %load_ext autoreload
# %autoreload 2

import numpy as np
import uuid
import time
import pickle
import gzip
from functools import partial

from tqdm.notebook import tqdm
from tenpy.tools import hdf5_io
import h5py

import matplotlib.pyplot as plt

from qphaset.cluster import model_cluster_qs_mps
from qphaset.models import drmg_gstate_qs_mps

# %% [markdown]
# ## Template notebook for running the DMRG for the Cluster model with `qs-mps`

# %%
def guess_state(L):
    """
    guess_state

    This function gives you a product state tensor of all up spins
    for a chain of length L
    
    """
    up = np.array([[[1],[0]]])
    init_tensor = [up for _ in range(L)]
    return init_tensor

def run_model(params, model_factory, gstate_solver):
    t_tot = []
    g_states = []
    for (x,y) in tqdm(params):
        print(f"x: {x}, y:{y}")
        model = model_factory(x, y)
        try:
            print("try with guess state...")
            if y == params[0,-1]:
                init_tensor = guess_state(model.L)
                model.sites = init_tensor.copy()
                model.enlarge_chi()
            else:
                model.sites = init_tensor.copy()
            timer = time.monotonic()
            gstate = gstate_solver(model=model)
            timer = time.monotonic() - timer
        except:
            print("try with random state...")
            model._random_state(seed=3, type_shape="rectangular")
            model.canonical_form()
            timer = time.monotonic()
            gstate = gstate_solver(model=model)
            timer = time.monotonic() - timer
        t_tot.append(timer)
        g_states.append(model.sites.copy())
        init_tensor = model.sites.copy()
    statistics = dict(times=t_tot)
    return g_states, statistics

# %%
# *** Data sampling (Hamitonian parameters grid) ***

n = 30  # Sampling grid size

# params = np.linspace(0.01, 1.5, n), np.linspace(0.01, 1.5, n)
params = np.linspace(0.5, 1.5, n), np.linspace(1.5, 0.5, n) # upside-down
# params = np.linspace(0.1, 0.3, n), np.linspace(0.3, 0.1, n) # upside-down
# params = np.linspace(0.01, 1., n), np.linspace(1., 0.01, n)   # Good one
# params = np.linspace(0.5, 1.5, n), np.linspace(1., 0.2, n)      # Floating phase detail
# params = np.linspace(0.5, 1.5, n), np.linspace(0.8, 0.01, n)      # Floating phase detail (lowered)
# params = np.linspace(0.01, 1., n), np.linspace(0.8, 0.01, n)      # Floating phase detail (lowered) + multi-critical point
# params = np.linspace(0.6, 1.5, n), np.linspace(0.1, 1.5, n)      # Floating phase detail ++

params = map(lambda m: m.flatten(), np.meshgrid(*params, indexing='xy'))
params = tuple(params)
params = np.stack(params).T

# %%
# *** Config ***

l = 12  # Number of spins

model_name = 'Cluster'
model_factory = partial(model_cluster_qs_mps, c1=1e-3, chi=64)
dmrg_params = {
    #'mixer': True,
    #'max_E_err': 1.e-16,
    #'chi_list': {0: 25, 10: 50, 20: 100},
    'type_shape': "rectangular",
    'trunc_params': {
       'trunc_tol': False,
       'trunc_chi': True
    #   'svd_min': 1.e-16
    },
    'd': 2,
    'max_hours': 16 / 3600
    #'combine': True
}

# %%
# *** Solver ***

gstates, stats = run_model(params,
                        model_factory=partial(model_factory, l=l),
                        gstate_solver=partial(drmg_gstate_qs_mps, dmrg_params=dmrg_params))
# Out:
#   0%|          | 0/900 [00:00<?, ?it/s]
# x: 0.5, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:1.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:1.4655172413793103
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:1.4310344827586208
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:1.396551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:1.3620689655172413
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:1.3275862068965516
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:1.293103448275862
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:1.2586206896551724
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:1.2241379310344827
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:1.1896551724137931
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:1.1551724137931034
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:1.1206896551724137
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:1.0862068965517242
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:1.0517241379310345
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:1.0172413793103448
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:0.9827586206896551
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:0.9482758620689655
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:0.9137931034482759
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# ...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:0.7068965517241379
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:0.6724137931034483
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:0.6379310344827587
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:0.603448275862069
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:0.5689655172413793
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:0.5344827586206897
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5344827586206896, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.5689655172413793, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.603448275862069, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6379310344827587, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.6724137931034483, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7068965517241379, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7413793103448276, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.7758620689655172, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8103448275862069, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8448275862068966, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.8793103448275862, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9137931034482758, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9482758620689655, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 0.9827586206896551, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0172413793103448, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0517241379310345, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.0862068965517242, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1206896551724137, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1551724137931034, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.1896551724137931, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2241379310344827, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.2586206896551724, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.293103448275862, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3275862068965516, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.3620689655172413, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.396551724137931, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4310344827586206, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.4655172413793103, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1
#
# x: 1.5, y:0.5
# try with guess state...
# Sweep n: 0
#
# Sweep n: 1

# %%
# *** Execution time per pixel ***

plt.matshow(np.array(stats['times']).reshape((n, n)), cmap='hot', origin='lower')
plt.colorbar()

# %% [markdown]
# ## Save `pickle`

# %%
# *** Data export ***
filename = f'D:/code/projects/3_CLUSTER/results/data/{model_name}-{str(uuid.uuid4())}.pkl' 
data = dict(params=params, dmrg_params=dmrg_params,
            l=l, n=n, model_name=model_name,
            gstates=gstates, stats=stats)
with gzip.open(filename, 'wb') as f:
    pickle.dump(data, f)

# %% [markdown]
# ## Save `hdf5`

# %%
data = dict(params=params, dmrg_params=dmrg_params,
            l=l, n=n, model_name=model_name,
            gstates=gstates, stats=stats)

# %%
# Looking at the extent of the parameters explored (all just double checking all is okay!)
params_extent = np.concatenate([np.min(params, axis=0), np.max(params, axis=0)])
params_extent = tuple(params_extent[[0, 2, 1, 3]])
print(params_extent)
print(np.shape(params))
# Out:
# (0.1, 0.3, 0.1, 0.3)
# (400, 2)

# %%
# Taking the tensors
tensor_list =  data["gstates"]

# Convert the list to a 64x64 nested list
matrix_64x64 = [tensor_list[i*64:(i+1)*64] for i in range(64)]
# Flip the nested list vertically
flipped_matrix = matrix_64x64[::-1]
# Flatten the nested list back into a single list
corrected_list = [item for sublist in flipped_matrix for item in sublist]

# %%
# Creating data dictionary to be saved 
data_h5 = {#"gstates": gstates,  # list of MPS - tensors 
        "gstates": corrected_list, # Flipped list
        "params_extent": params_extent, # (2, N) evenly spaced - in future 
        "n": data["n"],
        "l": data["l"], # Number of qubits (L)
        "dmrg_params": data["dmrg_params"], # DMRG params used in calculation - converting? hashtable 
        "info": {"model_type":"Cluster",}, # Additional info 
        "times": np.array(data["stats"]["times"]), # Times for DMRG } # params swept 
}

# %%
# Saving your file, make sure to change the name to the name you want to store your file in! 
filename_to_save = f"D:/code/projects/3_CLUSTER/results/data/{model_name}-{str(uuid.uuid4())}.h5"
with h5py.File(filename_to_save, 'w') as f:
    hdf5_io.save_to_hdf5(f, data_h5)
